# %%
import requests
import os
import pandas as pd

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
RAPIDAPI_KEY = os.environ["RAPIDAPI_KEY"]

# %%
url = "https://meteostat.p.rapidapi.com/stations/nearby"

params = {"lat":"49.298031137338704","lon":"19.949911081709388"}

headers = {
	"x-rapidapi-key": RAPIDAPI_KEY,
	"x-rapidapi-host": "meteostat.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=params)

data = response.json()["data"]

# %%
station_ids = ["12625", "12650", "11934"]

# %%
dfs = []
for station_id in station_ids:
    url = "https://meteostat.p.rapidapi.com/stations/daily"
    
    params = {"station": station_id, "start":"2020-01-01", "end":"2025-01-01"}
    
    headers = {
    	"x-rapidapi-key": RAPIDAPI_KEY,
    	"x-rapidapi-host": "meteostat.p.rapidapi.com",
    	"Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers, params=params)
    data = response.json()["data"]
    df = pd.DataFrame(data)
    df["station_id"] = station_id
    dfs.append(df)

# %%
df_api_data = df_api_data = pd.concat(dfs, axis=0).reset_index(drop=True)
# Out:
# C:\Users\mbdlu\AppData\Local\Temp\ipykernel_23004\1035354382.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_api_data = df_api_data = pd.concat(dfs, axis=0).reset_index(drop=True)

# %%
df_api_data = df_api_data.replace({"12625": "Zakopane", "12650": "Kasprowy Wierch", "11934": "Poprad/Tatry"})

# %%
columns_dict_rename = {
    "tavg": "avg_temp",
    "tmin": "min_temp",
    "tmax": "max_temp",
    "prcp": "precipitation_total_mm",
    "snow": "max_snow_dept_mm",
    "wdir": "wind_direction",
    "wspd": "avg_wind_speed_km/h",
    "wpgt": "max_wind_speed",
    "pres": "pressure",
    "tsun": "sunshine_total_min",
    "station_id": "station_name"
}

# %%
df_api_data = df_api_data.rename(columns_dict_rename, axis=1)

# %%
df_api_data.to_csv("data/station_daily.csv", index=False)
